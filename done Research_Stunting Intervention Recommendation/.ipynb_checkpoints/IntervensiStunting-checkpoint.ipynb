# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
intervensi_df = pd.read_csv('dataset_intervensi_stunting_revisi.csv', sep=';')

# %%
intervensi_df.head()
# Out:
#    usia_ibu pendidikan_terakhir  pekerjaan  jarak_ke_faskes_km  jumlah_anak  \
# 0        24                 SMP        IRT               11.28            4
# 1        37                 SMP  Wirausaha               12.15            4
# 2        32                  SD      Buruh               15.78            2
# 3        28                 SMA      Buruh                9.88            2
# 4        25                 SMA        IRT                1.29            3
#
#   status_pernikahan kepesertaan_BPJS  frekuensi_kunjungan_hamil  \
# 0           Menikah               Ya                          3
# 1           Menikah               Ya                          2
# 2     Belum Menikah               Ya                          3
# 3           Menikah               Ya                          2
# 4           Menikah               Ya                          1
#
#    usia_anak_bulan  berat_badan_kg  tinggi_badan_cm status_imunisasi  \
# 0               43             8.2             87.0          Lengkap
# 1                7             6.0             64.0    Tidak Lengkap
# 2               41            13.9             88.3          Lengkap
# 3               59            16.1            105.4          Lengkap
# 4               31             5.5             79.8          Lengkap
#
#         status_asi jenis_kelamin riwayat_diare_infeksi nafsu_makan_anak  \
# 0        Eksklusif     Laki-laki                 Tidak            Cukup
# 1        Eksklusif     Laki-laki                 Tidak           Banyak
# 2        Eksklusif     Perempuan                 Tidak            Cukup
# 3        Eksklusif     Laki-laki                 Tidak            Cukup
# 4  Tidak Eksklusif     Perempuan                 Tidak            Cukup
#
#    frekuensi_makan_per_hari                  pencegahan
# 0                         2  Pemberian Makanan Tambahan
# 1                         4  Kontrol Rutin ke Puskesmas
# 2                         2  Pemberian Makanan Tambahan
# 3                         4  Kontrol Rutin ke Puskesmas
# 4                         4  Kontrol Rutin ke Puskesmas

# %%
X = intervensi_df.drop("pencegahan", axis=1)
y = intervensi_df["pencegahan"]

# %%
from sklearn.preprocessing import OrdinalEncoder

categorical_cols = X.select_dtypes(include="object").columns
encoder = OrdinalEncoder()
X[categorical_cols] = encoder.fit_transform(X[categorical_cols])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.9, random_state=101)

# Train model
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)

# Evaluate
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#                             precision    recall  f1-score   support
#
#               Edukasi Gizi       0.60      0.43      0.50        14
# Kontrol Rutin ke Puskesmas       0.83      0.83      0.83        30
#                    Lainnya       0.71      0.61      0.66        36
# Pemberian Makanan Tambahan       0.85      0.96      0.90        70
#
#                   accuracy                           0.80       150
#                  macro avg       0.75      0.71      0.72       150
#               weighted avg       0.79      0.80      0.79       150

# %%
new_data = pd.DataFrame([{
    'usia_ibu': 27,
    'pendidikan_terakhir': 'SMA',
    'pekerjaan': 'IRT',
    'jarak_ke_faskes_km': 4.0,
    'jumlah_anak': 3,
    'status_pernikahan': 'Menikah',
    'kepesertaan_BPJS': 'Ya',
    'frekuensi_kunjungan_hamil': 1,  # KUNJUNGAN RENDAH
    'usia_anak_bulan': 18,
    'berat_badan_kg': 11.0,
    'tinggi_badan_cm': 85,
    'status_imunisasi': 'Lengkap',
    'status_asi': 'Eksklusif',
    'jenis_kelamin': 'Laki-laki',
    'riwayat_diare_infeksi': 'Tidak',
    'nafsu_makan_anak': 'Cukup',
    'frekuensi_makan_per_hari': 3
}])

# %%
# Salin dan encode
new_data_encoded = new_data.copy()
new_data_encoded[categorical_cols] = encoder.transform(new_data_encoded[categorical_cols])

new_data_encoded = new_data_encoded[X.columns]

new_data_scaled = scaler.transform(new_data_encoded)

prediksi_intervensi = model.predict(new_data_scaled)
print("Rekomendasi intervensi:", prediksi_intervensi[0])
# Out:
# Rekomendasi intervensi: Kontrol Rutin ke Puskesmas
